# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
election = pd.DataFrame.from_csv('FEC/fec.csv', index_col=None)
election.head()
# Out:
#              cmte_id       cand_id                    cand_nm  recipient_nm  \
# C00458844  P60006723  Rubio, Marco       FLOWERS HOPE NETWORK         69.49
# C00458844  P60006723  Rubio, Marco                 US AIRWAYS        223.10
# C00458844  P60006723  Rubio, Marco  AMERICAN EXPRESS-MERCHANT       2068.31
# C00458844  P60006723  Rubio, Marco  AMERICAN EXPRESS-MERCHANT        221.03
# C00458844  P60006723  Rubio, Marco                 US AIRWAYS        493.10
#
#             disb_amt  disb_dt recipient_city recipient_st  recipient_zip  \
# C00458844  26-MAY-15     HOPE             AR        71801        FLOWERS
# C00458844  19-JUN-15    TEMPE             AZ        85281         TRAVEL
# C00458844  29-JUN-15  PHOENIX             AZ        85072  MERCHANT FEES
# C00458844  06-APR-15  PHOENIX             AZ        85072  MERCHANT FEES
# C00458844  20-APR-15  PHOENIX             AZ    850343802         TRAVEL
#
#           disb_desc memo_cd memo_text  form_tp    file_num tran_id  \
# ...

# %%
election[election.recipient_nm > 100000]
# Out:
#              cmte_id                    cand_id  \
# C00458844  P60006723               Rubio, Marco
# C00458844  P60006723               Rubio, Marco
# C00500587  P20003281     Perry, James R. (Rick)
# C00500587  P20003281     Perry, James R. (Rick)
# C00573519  P60005915        Carson, Benjamin S.
# C00573519  P60005915        Carson, Benjamin S.
# C00573519  P60005915        Carson, Benjamin S.
# C00573519  P60005915        Carson, Benjamin S.
# C00573519  P60005915        Carson, Benjamin S.
# C00573519  P60005915        Carson, Benjamin S.
# C00573519  P60005915        Carson, Benjamin S.
# C00573519  P60005915        Carson, Benjamin S.
# C00573519  P60005915        Carson, Benjamin S.
# C00573519  P60005915        Carson, Benjamin S.
# C00573519  P60005915        Carson, Benjamin S.
# C00573519  P60005915        Carson, Benjamin S.
# C00574624  P60006111  Cruz, Rafael Edward 'Ted'
# C00574624  P60006111  Cruz, Rafael Edward 'Ted'
# ...

# %%
e = election
(e.cand_id).value_counts().sort_index().plot(kind='bar')

# %%
(election[election.recipient_nm > 100000].cand_id).value_counts().sort_index().plot(kind='bar')

# %%
e = election
e = e[e.recipient_zip == 'TRAVEL']
(e.cand_id).value_counts().sort_index().plot(kind='bar')
